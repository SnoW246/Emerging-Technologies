# %% [markdown]
# # Problem set: Jupyter, pyplot and numpy
# ## Fisher’s Iris Data Set
#
# The Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist [Ronald Fisher](https://en.wikipedia.org/wiki/Ronald_Fisher).
# This data set was used as an example of [linear discriminant analysis](https://en.wikipedia.org/wiki/Linear_discriminant_analysis) in his 1936 paper *The use of multiple measurements in taxonomic problems*.
#
# #### *The data set consists of 50 samples from each of three species of Iris*
# * *Iris setosa*
# * *Iris virginica*
# * *Iris versicolor*
#
# #### *Four features were measured from each sample*
# * *The length & the width of the sepals , in centimetres.(cm)*
# * *The length & the width of the petals , in centimetres.(cm)*
#
# Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other. More information can be found [here](https://en.wikipedia.org/wiki/Iris_flower_data_set).
#
# Original Python Problem sheet can be found [here](https://emerging-technologies.github.io/problems/jupyter.html)

# %%
# Importing libraries
import numpy as np
import matplotlib.pyplot as plt

# Adapted from https://stackoverflow.com/questions/332289/how-do-you-change-the-size-of-figures-drawn-with-matplotlib
# Changing default plot size
plt.rcParams['figure.figsize'] = (16.0, 8.0)

# %% [markdown]
# ### *Problem #1 - Get and load the data*

# %%
# Declaration of for the data file path for the numpy array, giving instructions which columns to use
# Adapted from https://stackoverflow.com/questions/3518778/how-to-read-csv-into-record-array-in-numpy
irisData = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=1, usecols=(0,1,2,3))

sepalLength = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=1, usecols=0)
sepalWidth = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=1, usecols=1)

petalLength = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=1, usecols=2)
petalWidth = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=1, usecols=3)

setosa = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=1, usecols=(0,1,2,3), max_rows=50)
versicolor = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=51, max_rows=50)
virginica = np.genfromtxt('Fishers-Iris-Data.csv', delimiter=',', skip_header=101, max_rows=50)

# Below are commands to display individual data sets from the csv file that was read
# Use one of the below to inspect the data output (comment out irisData to show none)
irisData
#sepalLength
#sepalWidth
#petalLength
#petalWidth
#setosa
#versicolor
#virginica
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.2,  3.5,  1.5,  0.2],
# ...

# %% [markdown]
# ### *Problem #3 - Create a simple plot*

# %%
# Declaration of the x, y axis & labels of the plot
plt.plot(sepalLength, sepalWidth, 'k.', label='Iris sepal data')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Iris Data - Sepal Length vs Sepal Width - Simple Graph')
plt.legend()
# Displaying the graph
plt.show()

# %% [markdown]
# ### *Problem #4 - Create a more complex plot*

# %%
# Adapted from https://plot.ly/python/ipython-notebook-tutorial/
# Declaration amd labeling of individual iris group points, using extended slices syntax [begin:end:step] to achieve that
plt.plot(sepalLength[0:50:1], sepalWidth[0:50:1], 'r.', label='Setosa')
plt.plot(sepalLength[50:100:1], sepalWidth[50:100:1], 'g.', label='Versicolor')
plt.plot(sepalLength[100:150:1], sepalWidth[100:150:1], 'b.', label='Virginica')
# Displaying individual labels
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Iris Data - Sepal Length vs Sepal Width - Complex Graph')
plt.legend()
# Displaying the graph
plt.show()

# %% [markdown]
# ### *Problem #5 - Use seaborn*

# %%
# Adapted from https://stackoverflow.com/questions/26597116/seaborn-plots-not-showing-up & http://seaborn.pydata.org/examples/scatterplot_matrix.html
import seaborn as sns
sns.set(style="ticks")

df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
plt.show()

# %% [markdown]
# ### *Problem #6 - Fit a line*

# %%
# Declaration of a best fit for the slope line
m, c = np.polyfit(petalLength, petalWidth, 1)
# Displaying the values for the best fit of the slope line
print("Best fit is m = %f and c = %f" % (m, c))

# Plotting data & line of best fit onto a scatter graph
plt.plot(petalLength, petalWidth, 'k.', label='Iris Petal Data')
plt.plot(petalLength, m * petalLength + c, 'b-', label='Best fit: $%0.1f x + %0.1f$' % (m,c))
# Declaration of labels
plt.title('Iris Data - Petal Length and Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend()
# Displaying the graph
plt.show()
# Out:
# Best fit is m = 0.416419 and c = -0.366514

# %% [markdown]
# ### *Problem #7 - Calculate the R-squared value*

# %%
# Calculate the R-squared value for the line of the best fit displayed above
rsq = 1.0 - (np.sum((petalWidth - m * petalLength - c)**2)/np.sum((petalWidth - np.mean(petalWidth))**2))
print("The R-squared value is: %6.4f" % rsq)

# Calculate same value using numpy
print("The R-squared value calculated by numpy is: ")
np.corrcoef(petalLength, petalWidth)[0][1]**2
# Out:
# The R-squared value is: 0.9269
# The R-squared value calculated by numpy is:
# 0.92690122792200402

# %% [markdown]
# ### *Problem #8 - Fit another line for Setosa petals only*

# %%
# Declaration of a best fit for the slope line
m, c = np.polyfit(petalLength[0:50:1], petalWidth[0:50:1], 1)
# Displaying the values for the best fit of the slope line
print("Best fit is m = %f and c = %f" % (m, c))

# Plotting Setosa data & line of best fit onto a scatter graph
plt.plot(petalLength[0:50:1], petalWidth[0:50:1], 'r.', label='Setosa Petal data')
plt.plot(petalLength[0:50:1], m * petalLength[0:50:1] + c, 'b-', label='Best fit: $%0.1f x + %0.1f$' % (m,c))
plt.title('Iris Data - Setosa Petal Data')
plt.legend()
plt.show()
# Out:
# Best fit is m = 0.189262 and c = -0.033080

# %% [markdown]
# ### *Problem #9 - Calculate the R-squared value again*

# %%
# Calculate the R-squared value for the line of the best fit displayed above
rsq = 1.0 - (np.sum((petalWidth[0:50:1] - m * petalLength[0:50:1] - c)**2)/np.sum((petalWidth[0:50:1] - np.mean(petalWidth[0:50:1]))**2))
print("The R-squared value is %6.4f" % rsq)

# Calculate same value using numpy
print("The R-squared value calculated by numpy is: ")
np.corrcoef(petalLength[0:50:1], petalWidth[0:50:1])[0][1]**2
# Out:
# The R-squared value is -0.0414
# The R-squared value calculated by numpy is:
# 0.093824720222835681

# %% [markdown]
# ### *Problem #9 - Use gradient descent*

# %%
# Adapted from https://plot.ly/python/ipython-notebook-tutorial/
# Defining best fit slope values
def mGradient(x, y, m, c):
  return -2.0 * np.sum(x * (y - m * x - c))
def cGradient(x, y, m , c):
  return -2.0 * np.sum(y - m * x - c)

eta = 0.0001
m, c = 1.0, 1.0
change = True

# While loop to itterate through all of the values and carry out calculation
while change:
  mNew = m - eta * mGradient(petalLength[0:50:1], petalWidth[0:50:1], m, c)
  cNew = c - eta * cGradient(petalLength[0:50:1], petalWidth[0:50:1], m, c)
  if m == mNew and c == cNew:
    change = False
  else:
    m, c = mNew, cNew

print("m: %20.16f  c: %20.16f" % (m, c))
# Out:
# m:   0.1892624728849683  c:  -0.0330802603035933

# %% [markdown]
# ### *Best fit is values comparison:*
#
# |  Best Fit Method  | Value of M         | Value of C          |
# |-------------------|--------------------|---------------------|
# |  Numpy Polyfit    | 0.189262           | -0.033080           |
# |  Gradient Descent | 0.1892624728849683 | -0.0330802603035933 |
#
# Overall both methods are really accurate, but Gradient Descent method gains the advantage when it comes to precision providing longer decimal number results, so when there would be humongous data sets being tested Gradient Descent method would remain accurate whyle Numpy Polyfit method would differ alot more.
